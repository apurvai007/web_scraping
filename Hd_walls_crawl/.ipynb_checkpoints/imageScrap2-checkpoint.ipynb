# %%
import requests as req
from bs4 import BeautifulSoup
import ssl

# %%
# Ignore ssl certificate error
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input("Enter url : ")
r1  = req.get(url)
soup  = BeautifulSoup(r1.text,"html.parser")


link = []

x = soup.select('img[src^="https://images.pexels.com/photos"]')
print(x)
# Out:
# Enter url : https://www.pexels.com/@hiteshchoudhary
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b512207519d6> in <module>()
#      11 link = []
#      12
# ---> 13 x = soup1.select('img[src^="https://images.pexels.com/photos"]')
#      14 print(x)
#
# NameError: name 'soup1' is not defined
