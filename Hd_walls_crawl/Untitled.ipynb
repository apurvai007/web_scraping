# %%
import requests as req
import pandas as pd
from bs4 import *
import ssl

# %%
#ignore ssl certificate error
ctx = ssl.create_default_context()
ctx.host_name = False
ctx.verfy_mode = ssl.CERT_NONE

# %%
url = req.get("https://www.vtu4u.com/result/1cr17cs018/sem-4/rs-22/get")

# %%
soup = BeautifulSoup(url.text,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html ng-app="ResvtuApp">
#  <title ng-bind="title">
#   VTU4U - VTU Results | Class Rank | Previous SEM Results
#  </title>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="http://vtu4u.com" property="og:url">
#    <meta content="Vtu Results" property="og:type">
#     <meta content="Vtu Results | Vtu4u | Class Rank" property="og:title"/>
#     <meta content="Vtu Results, Vtu Results by class, Vtu CBCS &amp; NON CBCS Results" property="og:description"/>
#     <meta content="https://www.vtu4u.com/img/Vtu4u-logo.png" property="og:image"/>
#     <meta content="4QL3NpEcPMi0s3CoBJIZ8bI2Yl2Vy1ZnRt7d-CCqUyg" name="google-site-verification"/>
#     <meta content="!" name="fragment"/>
# ...

# %%
import json

url1 = 'https://www.vtu4u.com/result/1cr17cs018/sem-4/rs-22/get'
r = req.get(url1)

print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html ng-app="ResvtuApp">\n<title ng-bind="title">\n \nVTU4U - VTU Results | Class Rank | Previous SEM Results\n</title>\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\n<meta property="og:url" content="http://vtu4u.com" />\n<meta property="og:type" content="Vtu Results" />\n<meta property="og:title" content="Vtu Results | Vtu4u | Class Rank" />\n<meta property="og:description" content="Vtu Results, Vtu Results by class, Vtu CBCS & NON CBCS Results" />\n<meta property="og:image" content="https://www.vtu4u.com/img/Vtu4u-logo.png" />\n<meta name="google-site-verification" content="4QL3NpEcPMi0s3CoBJIZ8bI2Yl2Vy1ZnRt7d-CCqUyg" />\n<meta name="fragment" content="!" />\n<meta name="csrf-token" content="BTqNYUde7ALHbDjx8MFyzFZXVwOpxIZzi6dS45qX">\n<link rel="stylesheet" 
# ...
